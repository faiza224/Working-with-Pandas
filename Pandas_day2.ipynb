# %%
import numpy as np

import pandas as pd

# %%
titanic_df = pd.read_csv(r"C:\Users\faiza\Documents\Python-Learning\Python_Notes\Datasets\titanic.csv")

# %%
titanic_df.head()

# %%
titanic_df.index

# %%
type(titanic_df)

# %%
titanic_df.columns

# %%
#how many people were on titanic?
len(titanic_df)

# %%
#how much fare was collected
titanic_df.fare.sum()

# %%
#what was the average fare?
titanic_df.fare.mean()

# %%
#how much was the maximum fare?
titanic_df.fare.max()

# %%
titanic_df.sex.count()

# %%
titanic_df.sex.value_counts()

# %%
titanic_df['class'].value_counts()

# %%
titanic_df.embark_town.value_counts()
#x = titanic_df.embark_town.value_counts()

# %%
#x.index

# %%
#x.values

# %%
titanic_df.sex.value_counts()
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
titanic_df['class'].value_counts()

# %%
titanic_df.sex.value_counts()/len(titanic_df) * 100  # percentage of males and females in the ship
# Out:
# sex
# male      64.758698
# female    35.241302
# Name: count, dtype: float64

# %%
titanic_df.info()

# %%
titanic_df.describe()

# %%
titanic_df.head()
# Out:
#       sex   age     fare  class  embark_town alive
# 0    male  22.0   7.2500  Third  Southampton    no
# 1  female  38.0  71.2833  First    Cherbourg   yes
# 2  female  26.0   7.9250  Third  Southampton   yes
# 3  female  35.0  53.1000  First  Southampton   yes
# 4    male  35.0   8.0500  Third  Southampton    no

# %%
titanic_df.drop(columns= ["survived", "pclass","sibsp", "embarked", "who","deck","parch", "adult_male","alone"],inplace =True)

# %%
titanic_df
# Out:
#         sex   age     fare   class  embark_town alive
# 0      male  22.0   7.2500   Third  Southampton    no
# 1    female  38.0  71.2833   First    Cherbourg   yes
# 2    female  26.0   7.9250   Third  Southampton   yes
# 3    female  35.0  53.1000   First  Southampton   yes
# 4      male  35.0   8.0500   Third  Southampton    no
# ..      ...   ...      ...     ...          ...   ...
# 886    male  27.0  13.0000  Second  Southampton    no
# 887  female  19.0  30.0000   First  Southampton   yes
# 888  female   NaN  23.4500   Third  Southampton    no
# 889    male  26.0  30.0000   First    Cherbourg   yes
# 890    male  32.0   7.7500   Third   Queenstown    no
#
# [891 rows x 6 columns]

# %%
# how to make a new column

titanic_df['age_fare_sum'] = titanic_df['age']+titanic_df['fare']

# %%
titanic_df
# Out:
#         sex   age     fare   class  embark_town alive  age_fare_sum
# 0      male  22.0   7.2500   Third  Southampton    no       29.2500
# 1    female  38.0  71.2833   First    Cherbourg   yes      109.2833
# 2    female  26.0   7.9250   Third  Southampton   yes       33.9250
# 3    female  35.0  53.1000   First  Southampton   yes       88.1000
# 4      male  35.0   8.0500   Third  Southampton    no       43.0500
# ..      ...   ...      ...     ...          ...   ...           ...
# 886    male  27.0  13.0000  Second  Southampton    no       40.0000
# 887  female  19.0  30.0000   First  Southampton   yes       49.0000
# 888  female   NaN  23.4500   Third  Southampton    no           NaN
# 889    male  26.0  30.0000   First    Cherbourg   yes       56.0000
# 890    male  32.0   7.7500   Third   Queenstown    no       39.7500
#
# [891 rows x 7 columns]

# %%
# Export Data File
# titanic_df.to_clipboard                   # ctrl +c   you can paste anywhere

# %%
titanic_df.to_csv('titanic_new.csv')

# %%
print(titanic_df.to_string()) # if we want to check whole dataframe
# Out:
#         sex    age      fare   class  embark_town alive  age_fare_sum
# 0      male  22.00    7.2500   Third  Southampton    no       29.2500
# 1    female  38.00   71.2833   First    Cherbourg   yes      109.2833
# 2    female  26.00    7.9250   Third  Southampton   yes       33.9250
# 3    female  35.00   53.1000   First  Southampton   yes       88.1000
# 4      male  35.00    8.0500   Third  Southampton    no       43.0500
# 5      male    NaN    8.4583   Third   Queenstown    no           NaN
# 6      male  54.00   51.8625   First  Southampton    no      105.8625
# 7      male   2.00   21.0750   Third  Southampton    no       23.0750
# 8    female  27.00   11.1333   Third  Southampton   yes       38.1333
# 9    female  14.00   30.0708  Second    Cherbourg   yes       44.0708
# 10   female   4.00   16.7000   Third  Southampton   yes       20.7000
# 11   female  58.00   26.5500   First  Southampton   yes       84.5500
# ...

# %%
del titanic_df['age_fare_sum']

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sex          891 non-null    object
#  1   age          714 non-null    float64
#  2   fare         891 non-null    float64
#  3   class        891 non-null    object
#  4   embark_town  889 non-null    object
#  5   alive        891 non-null    object
# dtypes: float64(2), object(4)
# memory usage: 41.9+ KB

# %%
# to find missing values is in data frame

titanic_df.isna().sum()
# Out:
# sex              0
# age            177
# fare             0
# class            0
# embark_town      2
# alive            0
# dtype: int64

# %%
titanic_df.age.mean()
# Out:
# np.float64(29.69911764705882)

# %%
titanic_df.fillna(titanic_df['age'].mean(), inplace= True)

# %%
titanic_df
# Out:
#         sex        age     fare   class  embark_town alive
# 0      male  22.000000   7.2500   Third  Southampton    no
# 1    female  38.000000  71.2833   First    Cherbourg   yes
# 2    female  26.000000   7.9250   Third  Southampton   yes
# 3    female  35.000000  53.1000   First  Southampton   yes
# 4      male  35.000000   8.0500   Third  Southampton    no
# ..      ...        ...      ...     ...          ...   ...
# 886    male  27.000000  13.0000  Second  Southampton    no
# 887  female  19.000000  30.0000   First  Southampton   yes
# 888  female  29.699118  23.4500   Third  Southampton    no
# 889    male  26.000000  30.0000   First    Cherbourg   yes
# 890    male  32.000000   7.7500   Third   Queenstown    no
#
# [891 rows x 6 columns]
