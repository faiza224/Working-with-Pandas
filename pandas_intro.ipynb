# %%
import pandas as pd
import numpy as np

# %%
employee = { 
    "Name": ["Anil", "Sunil", "Mahesh", "John", "Peter"],
    "Age" : [24, 23, np.nan, 32, 35],
    "Salary": [10000, 15000, 20000, 25000, 30000]

}

# %% [markdown]
# To create DataFrame
# DataFrame_Name = pd.DataFrame(dictionary)

# %%
employee_df = pd.DataFrame(employee)

# %%
employee_df
# Out:
#      Name   Age  Salary
# 0    Anil  24.0   10000
# 1   Sunil  23.0   15000
# 2  Mahesh   NaN   20000
# 3    John  32.0   25000
# 4   Peter  35.0   30000

# %%
type(employee_df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(employee_df['Name'])
# Out:
# pandas.core.series.Series

# %%
#employee_df['Name']
employee_df['Age']
# Out:
# 0    24.0
# 1    23.0
# 2     NaN
# 3    32.0
# 4    35.0
# Name: Age, dtype: float64

# %%
# if you want to put more than 1 column , then put 2 square brackets to pass list 
employee_df[['Name', 'Age']]
# Out:
#      Name   Age
# 0    Anil  24.0
# 1   Sunil  23.0
# 2  Mahesh   NaN
# 3    John  32.0
# 4   Peter  35.0

# %%
employee_df.columns
# Out:
# Index(['Name', 'Age', 'Salary'], dtype='object')

# %%
employee_df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
employee_df.Salary.sum()
# Out:
# np.int64(100000)

# %%
employee_df.Age.mean()  #Average
# Out:
# np.float64(28.5)

# %%
employee_df.Salary.max()   #maximum Salary
# Out:
# np.int64(30000)

# %%
employee_df.Age.min()
# Out:
# np.float64(23.0)

# %%
employee_df.Salary.count() #  count of the number of salary
# Out:
# np.int64(5)

# %%
employee_df.Age.count() # number count of age
# Out:
# np.int64(4)
